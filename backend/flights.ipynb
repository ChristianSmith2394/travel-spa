# %%
from flask import Flask, request, jsonify
import pandas as pd
import json

data = json.load(open('flights.json'))['data']

dict_list = []
for d in range(len(data)):
    id = data[d]['id']
    price = data[d]['price']['total']
    for i in range(len(data[d]['itineraries'])):
        itinerary = i+1
        segment_list = []
        iDuration = data[d]['itineraries'][i]['duration']
        segments = len(data[d]['itineraries'][i]['segments'])
        for s in range(len(data[d]['itineraries'][i]['segments'])):
            segment = s+1
            departureCode = data[d]['itineraries'][i]['segments'][s]['departure']['iataCode']
            departureTime = data[d]['itineraries'][i]['segments'][s]['departure']['at']
            arrivalCode = data[d]['itineraries'][i]['segments'][s]['arrival']['iataCode']
            arrivalTime = data[d]['itineraries'][i]['segments'][s]['arrival']['at']
            carrierCode = data[d]['itineraries'][i]['segments'][s]['carrierCode']
            sDuration = data[d]['itineraries'][i]['segments'][s]['duration']

            segment_dict = {
                            'id': id,
                            'itinerary': itinerary,
                            'segment': segment, 
                            'segments': segments, 
                            'segDuration': sDuration,
                            'departureCode': departureCode,
                            'departureTime': departureTime, 
                            'arrivalCode': arrivalCode, 
                            'arrivalTime': arrivalTime, 
                            'price': price, 
                            'carrierCode': carrierCode, 
                            'itinDuration': iDuration
                            }
            segment_list.append(segment_dict)

        dict_list.append({f"{'Departure' if itinerary == 1 else 'Return'}": segment_list})


df = pd.DataFrame(dict_list)
data = df.to_dict('records')

# %%
data
# Out:
# [{'Departure': [{'id': '1',
#     'itinerary': 1,
#     'segment': 1,
#     'segments': 3,
#     'segDuration': 'PT2H31M',
#     'departureCode': 'ACY',
#     'departureTime': '2022-11-23T12:20:00',
#     'arrivalCode': 'MCO',
#     'arrivalTime': '2022-11-23T14:51:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT24H53M'},
#    {'id': '1',
#     'itinerary': 1,
#     'segment': 2,
#     'segments': 3,
#     'segDuration': 'PT1H40M',
#     'departureCode': 'MCO',
#     'departureTime': '2022-11-23T20:51:00',
#     'arrivalCode': 'ATL',
#     'arrivalTime': '2022-11-23T22:31:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT24H53M'},
#    {'id': '1',
#     'itinerary': 1,
#     'segment': 3,
#     'segments': 3,
#     'segDuration': 'PT2H43M',
#     'departureCode': 'ATL',
#     'departureTime': '2022-11-24T10:30:00',
#     'arrivalCode': 'MSP',
#     'arrivalTime': '2022-11-24T12:13:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT24H53M'}],
#   'Return': nan},
#  {'Departure': nan,
#   'Return': [{'id': '1',
#     'itinerary': 2,
#     'segment': 1,
#     'segments': 3,
#     'segDuration': 'PT1H42M',
#     'departureCode': 'MSP',
#     'departureTime': '2022-11-29T18:45:00',
#     'arrivalCode': 'DTW',
#     'arrivalTime': '2022-11-29T21:27:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT38H5M'},
#    {'id': '1',
#     'itinerary': 2,
#     'segment': 2,
#     'segments': 3,
#     'segDuration': 'PT1H50M',
#     'departureCode': 'DTW',
#     'departureTime': '2022-11-30T11:00:00',
#     'arrivalCode': 'MYR',
#     'arrivalTime': '2022-11-30T12:50:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT38H5M'},
#    {'id': '1',
#     'itinerary': 2,
#     'segment': 3,
#     'segments': 3,
#     'segDuration': 'PT1H20M',
#     'departureCode': 'MYR',
#     'departureTime': '2022-12-01T08:30:00',
#     'arrivalCode': 'ACY',
#     'arrivalTime': '2022-12-01T09:50:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT38H5M'}]},
#  {'Departure': [{'id': '2',
#     'itinerary': 1,
#     'segment': 1,
#     'segments': 3,
#     'segDuration': 'PT2H40M',
#     'departureCode': 'ACY',
#     'departureTime': '2022-11-23T10:25:00',
#     'arrivalCode': 'FLL',
#     'arrivalTime': '2022-11-23T13:05:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT26H48M'},
#    {'id': '2',
#     'itinerary': 1,
#     'segment': 2,
#     'segments': 3,
#     'segDuration': 'PT1H58M',
#     'departureCode': 'FLL',
#     'departureTime': '2022-11-23T19:00:00',
#     'arrivalCode': 'ATL',
#     'arrivalTime': '2022-11-23T20:58:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT26H48M'},
#    {'id': '2',
#     'itinerary': 1,
#     'segment': 3,
#     'segments': 3,
#     'segDuration': 'PT2H43M',
#     'departureCode': 'ATL',
#     'departureTime': '2022-11-24T10:30:00',
#     'arrivalCode': 'MSP',
#     'arrivalTime': '2022-11-24T12:13:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT26H48M'}],
#   'Return': nan},
#  {'Departure': nan,
#   'Return': [{'id': '2',
#     'itinerary': 2,
#     'segment': 1,
#     'segments': 3,
#     'segDuration': 'PT1H42M',
#     'departureCode': 'MSP',
#     'departureTime': '2022-11-29T18:45:00',
#     'arrivalCode': 'DTW',
#     'arrivalTime': '2022-11-29T21:27:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT38H5M'},
#    {'id': '2',
#     'itinerary': 2,
#     'segment': 2,
#     'segments': 3,
#     'segDuration': 'PT1H50M',
#     'departureCode': 'DTW',
#     'departureTime': '2022-11-30T11:00:00',
#     'arrivalCode': 'MYR',
#     'arrivalTime': '2022-11-30T12:50:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT38H5M'},
#    {'id': '2',
#     'itinerary': 2,
#     'segment': 3,
#     'segments': 3,
#     'segDuration': 'PT1H20M',
#     'departureCode': 'MYR',
#     'departureTime': '2022-12-01T08:30:00',
#     'arrivalCode': 'ACY',
#     'arrivalTime': '2022-12-01T09:50:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT38H5M'}]},
#  {'Departure': [{'id': '3',
#     'itinerary': 1,
#     'segment': 1,
#     'segments': 3,
#     'segDuration': 'PT2H40M',
#     'departureCode': 'ACY',
#     'departureTime': '2022-11-23T10:25:00',
#     'arrivalCode': 'FLL',
#     'arrivalTime': '2022-11-23T13:05:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT26H48M'},
#    {'id': '3',
#     'itinerary': 1,
#     'segment': 2,
#     'segments': 3,
#     'segDuration': 'PT1H56M',
#     'departureCode': 'FLL',
#     'departureTime': '2022-11-23T21:00:00',
#     'arrivalCode': 'ATL',
#     'arrivalTime': '2022-11-23T22:56:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT26H48M'},
#    {'id': '3',
#     'itinerary': 1,
#     'segment': 3,
#     'segments': 3,
#     'segDuration': 'PT2H43M',
#     'departureCode': 'ATL',
#     'departureTime': '2022-11-24T10:30:00',
#     'arrivalCode': 'MSP',
#     'arrivalTime': '2022-11-24T12:13:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT26H48M'}],
#   'Return': nan},
#  {'Departure': nan,
#   'Return': [{'id': '3',
#     'itinerary': 2,
#     'segment': 1,
#     'segments': 3,
#     'segDuration': 'PT1H42M',
#     'departureCode': 'MSP',
#     'departureTime': '2022-11-29T18:45:00',
#     'arrivalCode': 'DTW',
#     'arrivalTime': '2022-11-29T21:27:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT38H5M'},
#    {'id': '3',
#     'itinerary': 2,
#     'segment': 2,
#     'segments': 3,
#     'segDuration': 'PT1H50M',
#     'departureCode': 'DTW',
#     'departureTime': '2022-11-30T11:00:00',
#     'arrivalCode': 'MYR',
#     'arrivalTime': '2022-11-30T12:50:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT38H5M'},
#    {'id': '3',
#     'itinerary': 2,
#     'segment': 3,
#     'segments': 3,
#     'segDuration': 'PT1H20M',
#     'departureCode': 'MYR',
#     'departureTime': '2022-12-01T08:30:00',
#     'arrivalCode': 'ACY',
#     'arrivalTime': '2022-12-01T09:50:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT38H5M'}]},
#  {'Departure': [{'id': '4',
#     'itinerary': 1,
#     'segment': 1,
#     'segments': 3,
#     'segDuration': 'PT2H31M',
#     'departureCode': 'ACY',
#     'departureTime': '2022-11-23T12:20:00',
#     'arrivalCode': 'MCO',
#     'arrivalTime': '2022-11-23T14:51:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT29H21M'},
#    {'id': '4',
#     'itinerary': 1,
#     'segment': 2,
#     'segments': 3,
#     'segDuration': 'PT1H40M',
#     'departureCode': 'MCO',
#     'departureTime': '2022-11-23T20:51:00',
#     'arrivalCode': 'ATL',
#     'arrivalTime': '2022-11-23T22:31:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT29H21M'},
#    {'id': '4',
#     'itinerary': 1,
#     'segment': 3,
#     'segments': 3,
#     'segDuration': 'PT2H41M',
#     'departureCode': 'ATL',
#     'departureTime': '2022-11-24T15:00:00',
#     'arrivalCode': 'MSP',
#     'arrivalTime': '2022-11-24T16:41:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT29H21M'}],
#   'Return': nan},
#  {'Departure': nan,
#   'Return': [{'id': '4',
#     'itinerary': 2,
#     'segment': 1,
#     'segments': 3,
#     'segDuration': 'PT1H42M',
#     'departureCode': 'MSP',
#     'departureTime': '2022-11-29T18:45:00',
#     'arrivalCode': 'DTW',
#     'arrivalTime': '2022-11-29T21:27:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT38H5M'},
#    {'id': '4',
#     'itinerary': 2,
#     'segment': 2,
#     'segments': 3,
#     'segDuration': 'PT1H50M',
#     'departureCode': 'DTW',
#     'departureTime': '2022-11-30T11:00:00',
#     'arrivalCode': 'MYR',
#     'arrivalTime': '2022-11-30T12:50:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT38H5M'},
#    {'id': '4',
#     'itinerary': 2,
#     'segment': 3,
#     'segments': 3,
#     'segDuration': 'PT1H20M',
#     'departureCode': 'MYR',
#     'departureTime': '2022-12-01T08:30:00',
#     'arrivalCode': 'ACY',
#     'arrivalTime': '2022-12-01T09:50:00',
#     'price': '2325.50',
#     'carrierCode': 'NK',
#     'itinDuration': 'PT38H5M'}]}]

# %%
from flask import Flask, request, jsonify
import pandas as pd
import json

data = json.load(open('flights.json'))['data']

dict_list = []
for d in range(len(data)):
    id = data[d]['id']
    price = data[d]['price']['total']
    for i in range(len(data[d]['itineraries'])):
        itinerary = i+1
        iDuration = data[d]['itineraries'][i]['duration']
        segments = len(data[d]['itineraries'][i]['segments'])
        for s in range(len(data[d]['itineraries'][i]['segments'])):
            segment = s+1
            departureCode = data[d]['itineraries'][i]['segments'][s]['departure']['iataCode']
            departureTime = data[d]['itineraries'][i]['segments'][s]['departure']['at']
            arrivalCode = data[d]['itineraries'][i]['segments'][s]['arrival']['iataCode']
            arrivalTime = data[d]['itineraries'][i]['segments'][s]['arrival']['at']
            carrierCode = data[d]['itineraries'][i]['segments'][s]['carrierCode']
            sDuration = data[d]['itineraries'][i]['segments'][s]['duration']

            dict_list.append({
                            'id': id, 
                            'itinerary': itinerary,
                            'segment': segment, 
                            'segments': segments, 
                            'segDuration': sDuration,
                            'departureCode': departureCode,
                            'departureTime': departureTime, 
                            'arrivalCode': arrivalCode, 
                            'arrivalTime': arrivalTime, 
                            'price': price, 
                            'carrierCode': carrierCode, 
                            'itinDuration': iDuration
                            })


df = pd.DataFrame(dict_list)

df
# Out:
#    id  itinerary  segment  segments segDuration departureCode  \
# 0   1          1        1         3     PT2H31M           ACY
# 1   1          1        2         3     PT1H40M           MCO
# 2   1          1        3         3     PT2H43M           ATL
# 3   1          2        1         3     PT1H42M           MSP
# 4   1          2        2         3     PT1H50M           DTW
# 5   1          2        3         3     PT1H20M           MYR
# 6   2          1        1         3     PT2H40M           ACY
# 7   2          1        2         3     PT1H58M           FLL
# 8   2          1        3         3     PT2H43M           ATL
# 9   2          2        1         3     PT1H42M           MSP
# 10  2          2        2         3     PT1H50M           DTW
# 11  2          2        3         3     PT1H20M           MYR
# 12  3          1        1         3     PT2H40M           ACY
# 13  3          1        2         3     PT1H56M           FLL
# 14  3          1        3         3     PT2H43M           ATL
# 15  3          2        1         3     PT1H42M           MSP
# 16  3          2        2         3     PT1H50M           DTW
# 17  3          2        3         3     PT1H20M           MYR
# 18  4          1        1         3     PT2H31M           ACY
# 19  4          1        2         3     PT1H40M           MCO
# 20  4          1        3         3     PT2H41M           ATL
# 21  4          2        1         3     PT1H42M           MSP
# 22  4          2        2         3     PT1H50M           DTW
# 23  4          2        3         3     PT1H20M           MYR
#
#           departureTime arrivalCode          arrivalTime    price carrierCode  \
# 0   2022-11-23T12:20:00         MCO  2022-11-23T14:51:00  2325.50          NK
# 1   2022-11-23T20:51:00         ATL  2022-11-23T22:31:00  2325.50          NK
# 2   2022-11-24T10:30:00         MSP  2022-11-24T12:13:00  2325.50          NK
# 3   2022-11-29T18:45:00         DTW  2022-11-29T21:27:00  2325.50          NK
# 4   2022-11-30T11:00:00         MYR  2022-11-30T12:50:00  2325.50          NK
# 5   2022-12-01T08:30:00         ACY  2022-12-01T09:50:00  2325.50          NK
# 6   2022-11-23T10:25:00         FLL  2022-11-23T13:05:00  2325.50          NK
# 7   2022-11-23T19:00:00         ATL  2022-11-23T20:58:00  2325.50          NK
# 8   2022-11-24T10:30:00         MSP  2022-11-24T12:13:00  2325.50          NK
# 9   2022-11-29T18:45:00         DTW  2022-11-29T21:27:00  2325.50          NK
# 10  2022-11-30T11:00:00         MYR  2022-11-30T12:50:00  2325.50          NK
# 11  2022-12-01T08:30:00         ACY  2022-12-01T09:50:00  2325.50          NK
# 12  2022-11-23T10:25:00         FLL  2022-11-23T13:05:00  2325.50          NK
# 13  2022-11-23T21:00:00         ATL  2022-11-23T22:56:00  2325.50          NK
# 14  2022-11-24T10:30:00         MSP  2022-11-24T12:13:00  2325.50          NK
# 15  2022-11-29T18:45:00         DTW  2022-11-29T21:27:00  2325.50          NK
# 16  2022-11-30T11:00:00         MYR  2022-11-30T12:50:00  2325.50          NK
# 17  2022-12-01T08:30:00         ACY  2022-12-01T09:50:00  2325.50          NK
# 18  2022-11-23T12:20:00         MCO  2022-11-23T14:51:00  2325.50          NK
# 19  2022-11-23T20:51:00         ATL  2022-11-23T22:31:00  2325.50          NK
# 20  2022-11-24T15:00:00         MSP  2022-11-24T16:41:00  2325.50          NK
# 21  2022-11-29T18:45:00         DTW  2022-11-29T21:27:00  2325.50          NK
# 22  2022-11-30T11:00:00         MYR  2022-11-30T12:50:00  2325.50          NK
# 23  2022-12-01T08:30:00         ACY  2022-12-01T09:50:00  2325.50          NK
#
#    itinDuration
# 0      PT24H53M
# 1      PT24H53M
# 2      PT24H53M
# 3       PT38H5M
# 4       PT38H5M
# 5       PT38H5M
# 6      PT26H48M
# 7      PT26H48M
# 8      PT26H48M
# 9       PT38H5M
# 10      PT38H5M
# 11      PT38H5M
# 12     PT26H48M
# 13     PT26H48M
# 14     PT26H48M
# 15      PT38H5M
# 16      PT38H5M
# 17      PT38H5M
# 18     PT29H21M
# 19     PT29H21M
# 20     PT29H21M
# 21      PT38H5M
# 22      PT38H5M
# 23      PT38H5M

# %%
data
# Out:
# [{'type': 'flight-offer',
#   'id': '1',
#   'source': 'GDS',
#   'instantTicketingRequired': 'False',
#   'nonHomogeneous': 'False',
#   'oneWay': 'False',
#   'lastTicketingDate': '2022-11-22',
#   'numberOfBookableSeats': 9,
#   'itineraries': [{'duration': 'PT24H53M',
#     'segments': [{'departure': {'iataCode': 'ACY',
#        'at': '2022-11-23T12:20:00'},
#       'arrival': {'iataCode': 'MCO',
#        'terminal': '0',
#        'at': '2022-11-23T14:51:00'},
#       'carrierCode': 'NK',
#       'number': '531',
#       'aircraft': {'code': '32B'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT2H31M',
#       'id': '10',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'},
#      {'departure': {'iataCode': 'MCO',
#        'terminal': '0',
#        'at': '2022-11-23T20:51:00'},
#       'arrival': {'iataCode': 'ATL',
#        'terminal': 'N',
#        'at': '2022-11-23T22:31:00'},
#       'carrierCode': 'NK',
#       'number': '770',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT1H40M',
#       'id': '11',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'},
#      {'departure': {'iataCode': 'ATL',
#        'terminal': 'N',
#        'at': '2022-11-24T10:30:00'},
#       'arrival': {'iataCode': 'MSP',
#        'terminal': '1',
#        'at': '2022-11-24T12:13:00'},
#       'carrierCode': 'NK',
#       'number': '1081',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT2H43M',
#       'id': '12',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'}]},
#    {'duration': 'PT38H5M',
#     'segments': [{'departure': {'iataCode': 'MSP',
#        'terminal': '1',
#        'at': '2022-11-29T18:45:00'},
#       'arrival': {'iataCode': 'DTW',
#        'terminal': 'N',
#        'at': '2022-11-29T21:27:00'},
#       'carrierCode': 'NK',
#       'number': '1342',
#       'aircraft': {'code': '32B'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT1H42M',
#       'id': '13',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'},
#      {'departure': {'iataCode': 'DTW',
#        'terminal': 'N',
#        'at': '2022-11-30T11:00:00'},
#       'arrival': {'iataCode': 'MYR', 'at': '2022-11-30T12:50:00'},
#       'carrierCode': 'NK',
#       'number': '3039',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT1H50M',
#       'id': '14',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'},
#      {'departure': {'iataCode': 'MYR', 'at': '2022-12-01T08:30:00'},
#       'arrival': {'iataCode': 'ACY', 'at': '2022-12-01T09:50:00'},
#       'carrierCode': 'NK',
#       'number': '355',
#       'aircraft': {'code': '319'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT1H20M',
#       'id': '15',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'}]}],
#   'price': {'currency': 'USD',
#    'total': '2325.50',
#    'base': '1902.00',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '2325.50'},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': 'False'},
#   'validatingAirlineCodes': ['NK'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '10',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '11',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '12',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]},
#    {'travelerId': '2',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '10',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '11',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '12',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]},
#    {'travelerId': '3',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '10',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '11',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '12',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]},
#    {'travelerId': '4',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '10',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '11',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '12',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]},
#    {'travelerId': '5',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '10',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '11',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '12',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]}]},
#  {'type': 'flight-offer',
#   'id': '2',
#   'source': 'GDS',
#   'instantTicketingRequired': 'False',
#   'nonHomogeneous': 'False',
#   'oneWay': 'False',
#   'lastTicketingDate': '2022-11-22',
#   'numberOfBookableSeats': 9,
#   'itineraries': [{'duration': 'PT26H48M',
#     'segments': [{'departure': {'iataCode': 'ACY',
#        'at': '2022-11-23T10:25:00'},
#       'arrival': {'iataCode': 'FLL',
#        'terminal': '4',
#        'at': '2022-11-23T13:05:00'},
#       'carrierCode': 'NK',
#       'number': '1729',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT2H40M',
#       'id': '4',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'},
#      {'departure': {'iataCode': 'FLL',
#        'terminal': '4',
#        'at': '2022-11-23T19:00:00'},
#       'arrival': {'iataCode': 'ATL',
#        'terminal': 'N',
#        'at': '2022-11-23T20:58:00'},
#       'carrierCode': 'NK',
#       'number': '1078',
#       'aircraft': {'code': '32B'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT1H58M',
#       'id': '5',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'},
#      {'departure': {'iataCode': 'ATL',
#        'terminal': 'N',
#        'at': '2022-11-24T10:30:00'},
#       'arrival': {'iataCode': 'MSP',
#        'terminal': '1',
#        'at': '2022-11-24T12:13:00'},
#       'carrierCode': 'NK',
#       'number': '1081',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT2H43M',
#       'id': '6',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'}]},
#    {'duration': 'PT38H5M',
#     'segments': [{'departure': {'iataCode': 'MSP',
#        'terminal': '1',
#        'at': '2022-11-29T18:45:00'},
#       'arrival': {'iataCode': 'DTW',
#        'terminal': 'N',
#        'at': '2022-11-29T21:27:00'},
#       'carrierCode': 'NK',
#       'number': '1342',
#       'aircraft': {'code': '32B'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT1H42M',
#       'id': '13',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'},
#      {'departure': {'iataCode': 'DTW',
#        'terminal': 'N',
#        'at': '2022-11-30T11:00:00'},
#       'arrival': {'iataCode': 'MYR', 'at': '2022-11-30T12:50:00'},
#       'carrierCode': 'NK',
#       'number': '3039',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT1H50M',
#       'id': '14',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'},
#      {'departure': {'iataCode': 'MYR', 'at': '2022-12-01T08:30:00'},
#       'arrival': {'iataCode': 'ACY', 'at': '2022-12-01T09:50:00'},
#       'carrierCode': 'NK',
#       'number': '355',
#       'aircraft': {'code': '319'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT1H20M',
#       'id': '15',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'}]}],
#   'price': {'currency': 'USD',
#    'total': '2325.50',
#    'base': '1902.00',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '2325.50'},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': 'False'},
#   'validatingAirlineCodes': ['NK'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '4',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '5',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '6',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]},
#    {'travelerId': '2',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '4',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '5',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '6',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]},
#    {'travelerId': '3',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '4',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '5',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '6',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]},
#    {'travelerId': '4',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '4',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '5',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '6',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]},
#    {'travelerId': '5',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '4',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '5',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '6',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]}]},
#  {'type': 'flight-offer',
#   'id': '3',
#   'source': 'GDS',
#   'instantTicketingRequired': 'False',
#   'nonHomogeneous': 'False',
#   'oneWay': 'False',
#   'lastTicketingDate': '2022-11-22',
#   'numberOfBookableSeats': 9,
#   'itineraries': [{'duration': 'PT26H48M',
#     'segments': [{'departure': {'iataCode': 'ACY',
#        'at': '2022-11-23T10:25:00'},
#       'arrival': {'iataCode': 'FLL',
#        'terminal': '4',
#        'at': '2022-11-23T13:05:00'},
#       'carrierCode': 'NK',
#       'number': '1729',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT2H40M',
#       'id': '7',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'},
#      {'departure': {'iataCode': 'FLL',
#        'terminal': '4',
#        'at': '2022-11-23T21:00:00'},
#       'arrival': {'iataCode': 'ATL',
#        'terminal': 'N',
#        'at': '2022-11-23T22:56:00'},
#       'carrierCode': 'NK',
#       'number': '1232',
#       'aircraft': {'code': '32A'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT1H56M',
#       'id': '8',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'},
#      {'departure': {'iataCode': 'ATL',
#        'terminal': 'N',
#        'at': '2022-11-24T10:30:00'},
#       'arrival': {'iataCode': 'MSP',
#        'terminal': '1',
#        'at': '2022-11-24T12:13:00'},
#       'carrierCode': 'NK',
#       'number': '1081',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT2H43M',
#       'id': '9',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'}]},
#    {'duration': 'PT38H5M',
#     'segments': [{'departure': {'iataCode': 'MSP',
#        'terminal': '1',
#        'at': '2022-11-29T18:45:00'},
#       'arrival': {'iataCode': 'DTW',
#        'terminal': 'N',
#        'at': '2022-11-29T21:27:00'},
#       'carrierCode': 'NK',
#       'number': '1342',
#       'aircraft': {'code': '32B'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT1H42M',
#       'id': '13',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'},
#      {'departure': {'iataCode': 'DTW',
#        'terminal': 'N',
#        'at': '2022-11-30T11:00:00'},
#       'arrival': {'iataCode': 'MYR', 'at': '2022-11-30T12:50:00'},
#       'carrierCode': 'NK',
#       'number': '3039',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT1H50M',
#       'id': '14',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'},
#      {'departure': {'iataCode': 'MYR', 'at': '2022-12-01T08:30:00'},
#       'arrival': {'iataCode': 'ACY', 'at': '2022-12-01T09:50:00'},
#       'carrierCode': 'NK',
#       'number': '355',
#       'aircraft': {'code': '319'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT1H20M',
#       'id': '15',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'}]}],
#   'price': {'currency': 'USD',
#    'total': '2325.50',
#    'base': '1902.00',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '2325.50'},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': 'False'},
#   'validatingAirlineCodes': ['NK'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '7',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '8',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '9',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]},
#    {'travelerId': '2',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '7',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '8',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '9',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]},
#    {'travelerId': '3',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '7',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '8',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '9',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]},
#    {'travelerId': '4',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '7',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '8',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '9',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]},
#    {'travelerId': '5',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '7',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '8',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '9',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]}]},
#  {'type': 'flight-offer',
#   'id': '4',
#   'source': 'GDS',
#   'instantTicketingRequired': 'False',
#   'nonHomogeneous': 'False',
#   'oneWay': 'False',
#   'lastTicketingDate': '2022-11-22',
#   'numberOfBookableSeats': 9,
#   'itineraries': [{'duration': 'PT29H21M',
#     'segments': [{'departure': {'iataCode': 'ACY',
#        'at': '2022-11-23T12:20:00'},
#       'arrival': {'iataCode': 'MCO',
#        'terminal': '0',
#        'at': '2022-11-23T14:51:00'},
#       'carrierCode': 'NK',
#       'number': '531',
#       'aircraft': {'code': '32B'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT2H31M',
#       'id': '1',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'},
#      {'departure': {'iataCode': 'MCO',
#        'terminal': '0',
#        'at': '2022-11-23T20:51:00'},
#       'arrival': {'iataCode': 'ATL',
#        'terminal': 'N',
#        'at': '2022-11-23T22:31:00'},
#       'carrierCode': 'NK',
#       'number': '770',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT1H40M',
#       'id': '2',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'},
#      {'departure': {'iataCode': 'ATL',
#        'terminal': 'N',
#        'at': '2022-11-24T15:00:00'},
#       'arrival': {'iataCode': 'MSP',
#        'terminal': '1',
#        'at': '2022-11-24T16:41:00'},
#       'carrierCode': 'NK',
#       'number': '40',
#       'aircraft': {'code': '32A'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT2H41M',
#       'id': '3',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'}]},
#    {'duration': 'PT38H5M',
#     'segments': [{'departure': {'iataCode': 'MSP',
#        'terminal': '1',
#        'at': '2022-11-29T18:45:00'},
#       'arrival': {'iataCode': 'DTW',
#        'terminal': 'N',
#        'at': '2022-11-29T21:27:00'},
#       'carrierCode': 'NK',
#       'number': '1342',
#       'aircraft': {'code': '32B'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT1H42M',
#       'id': '13',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'},
#      {'departure': {'iataCode': 'DTW',
#        'terminal': 'N',
#        'at': '2022-11-30T11:00:00'},
#       'arrival': {'iataCode': 'MYR', 'at': '2022-11-30T12:50:00'},
#       'carrierCode': 'NK',
#       'number': '3039',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT1H50M',
#       'id': '14',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'},
#      {'departure': {'iataCode': 'MYR', 'at': '2022-12-01T08:30:00'},
#       'arrival': {'iataCode': 'ACY', 'at': '2022-12-01T09:50:00'},
#       'carrierCode': 'NK',
#       'number': '355',
#       'aircraft': {'code': '319'},
#       'operating': {'carrierCode': 'NK'},
#       'duration': 'PT1H20M',
#       'id': '15',
#       'numberOfStops': 0,
#       'blacklistedInEU': 'False'}]}],
#   'price': {'currency': 'USD',
#    'total': '2325.50',
#    'base': '1902.00',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '2325.50'},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': 'False'},
#   'validatingAirlineCodes': ['NK'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '1',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '2',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '3',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]},
#    {'travelerId': '2',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '1',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '2',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '3',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]},
#    {'travelerId': '3',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '1',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '2',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '3',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]},
#    {'travelerId': '4',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '1',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '2',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '3',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]},
#    {'travelerId': '5',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'USD', 'total': '465.10', 'base': '380.40'},
#     'fareDetailsBySegment': [{'segmentId': '1',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '2',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TNR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '3',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'TA3NR',
#       'class': 'T',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '13',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'U7XSNR',
#       'class': 'U',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '14',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GNR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}},
#      {'segmentId': '15',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'GA7NR',
#       'class': 'G',
#       'includedCheckedBags': {'quantity': 0}}]}]}]
